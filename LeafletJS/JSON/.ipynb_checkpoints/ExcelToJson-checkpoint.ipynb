# %%
import os
import pandas as pd
from pprint import pprint
import json

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lukeg\\Desktop\\Capstone Project\\LeafletJS\\JSON'

# %%
#os.chdir(r"C:\Users\Lukeg\Desktop\Capstone Project\LeafletJS\Node Excel Files")

folder = "csv files"
path = os.path.join(os.getcwd(), folder)

os.chdir(path)
csv_files = os.listdir(path)

# %%
print(csv_files)
# Out:
# ['A1.csv', 'B1.csv', 'H1.csv', 'M1.csv']

# %%
building_names = {
    "A": "Building A",
    "B": "Building B",
    "C": "Building C",
    "D": "Building D",
    "E": "Building E",
    "F": "F Building",
    "G": "Building G",
    "H": "Building H",
    "J": "Building J",
    "K": "Building K",
    "M": "Building M",
    "T": "Building T",
}

# %%
all_docs = {}
for file in csv_files:
    doc = pd.read_csv(file)
    name = file.replace(".csv", "")
    
    building_code = name[0]
    floor_number = name[1:]
    
    building_name = building_names[building_code]
    if building_name not in all_docs:
        all_docs[building_name] = {}
    all_docs[building_name][floor_number] = doc

# %%
object_types = ["room", "building_connection", "stairs", "elevator", "outside_exit", "bathroom", "eatery"]
connects_floorplans = ["stairs", "elevator", "building_connection"]

# %%
accepted_node_types = ["object", "turn", "intersection", "roundabout"]

# %%
def object_logic(row, rooms, exits):
    object_type = row['Object_category_type']
    if not isinstance(object_type, str):
        return rooms, exits
    object_type = object_type.lower().replace(" ", "")
    object_type_list = object_type.split(",")

    objects = row['Object']
    objects = objects.replace(" ", "")
    object_list = objects.split(",")

    doors = row['Door']
    if isinstance(doors, str):
        doors = doors.replace(" ", "")
        door_list = doors.split(",")
        
    
    exit_conns = row['Exit_Connections']
    exit_conns_list = []
    if isinstance(exit_conns, str):
        exit_conns = exit_conns.replace(" ", "")
        exit_conns_raw = exit_conns.split(",")
        for element in exit_conns_raw:
            clean = element.strip("[]")
            exit_entries = clean.split("|")
            exit_conns_list.append(exit_entries)
            
    
    door_counter = 0
    exits_counter = 0
    for i,entry in enumerate(object_type_list):
        selected_obj = object_list[i]
        if entry == "room":
            door = door_list[door_counter]

            if selected_obj not in rooms:
                rooms[selected_obj] = []
            rooms[selected_obj].append(door)
            door_counter += 1
        elif entry == "exit":
            # print("exit")
            # print(object_type_list)
            # print(exit_conns_list)
            exit_destination = exit_conns_list[exits_counter]
            if selected_obj not in exits:
                exits[selected_obj] = []
            exits[selected_obj].extend(exit_destination)
            exits_counter += 1

    return rooms, exits

# %%
def split_csv(value):
    if isinstance(value, str):
        return value.replace(" ", "").split(",")
    return []


def parse_exit_conns(value):
    if not isinstance(value, str):
        return []
    cleaned = value.replace(" ", "")
    return [item.strip("[]").split("|") for item in cleaned.split(",")]


def node_navigation(row, navigationGraph, roomToNode, exitToNode):

    node = row["Node"]
    connections = split_csv(row["Node_connections"])
    object_ids = split_csv(row["Object"])
    node_types = split_csv(str(row["Node_type"]).lower())
    object_types = split_csv(str(row["Object_type"]).lower())
    categories = split_csv(str(row["Object_category_type"]).lower())
    doors = split_csv(row["Door"])
    exit_conns = parse_exit_conns(row["Exit_Connections"])

    if node not in navigationGraph:
        navigationGraph[node] = {"connections": connections, "represents": []}

    represents = navigationGraph[node]["represents"]

    # Map short names → proper names
    SIMPLE_TYPES = {
        "int": "intersection",
        "turn": "turn",
        "roundabout": "roundabout"
    }

    # ------------------------------------------------------------
    # 1. Add simple node types FIRST (turn, intersection, etc.)
    # ------------------------------------------------------------
    has_only_simple = True
    for nt in node_types:
        if nt in SIMPLE_TYPES:
            represents.append({"type": SIMPLE_TYPES[nt]})
        else:
            has_only_simple = False

    # If node is ONLY a simple type with no objects, stop here
    if has_only_simple and not object_types:
        return navigationGraph, roomToNode, exitToNode

    # ------------------------------------------------------------
    # 2. Now add objects (room, stairs, exit, bathroom, etc.)
    # ------------------------------------------------------------
    door_idx = 0
    exit_idx = 0

    for obj_type, obj_id, cat in zip(object_types, object_ids, categories):

        rep = {"type": obj_type, "id": obj_id}

        if cat == "room":
            if door_idx < len(doors):
                rep["door"] = doors[door_idx]
                door_idx += 1
            roomToNode[obj_id] = node

        elif cat == "exit":
            if exit_idx < len(exit_conns):
                rep["goesTo"] = exit_conns[exit_idx]
                exit_idx += 1
            else:
                rep["goesTo"] = None
            exitToNode[obj_id] = node

        represents.append(rep)

    return navigationGraph, roomToNode, exitToNode

# %%
#print(doc.columns)
def floorplan_json_generator(doc):
    navigationGraph = {}
    roomToNode = {}
    entranceToNode = {}
    objects = {
        'rooms' : None,
        'exits' : None
              }
    rooms = {}
    exits = {}
    for index, row in doc.iterrows():

        rooms, exits = object_logic(row, rooms, exits)
        navigationGraph, roomToNode, exitToNode = node_navigation(row, navigationGraph, roomToNode, entranceToNode)


    # #Sorting to make consistent
    # navigationGraph = dict(sorted(
    #     navigationGraph.items(),
    #     key=lambda x: int(x[0].split("_")[1])
    #     if "_" in x[0] and x[0].split("_")[1].isdigit()
    #     else float('inf')
    # ))
    
    objects['rooms'] = rooms
    objects['exits'] = exits
    return navigationGraph, roomToNode, entranceToNode, objects

# %%
node_data = {}
for building, data in all_docs.items():
    building_code = building[-1]
    building_path = f"Floorplans/{building}"
    for floor in data:
        floorplan_code = f"{building_code}{floor}"
        svg_file = f"{floorplan_code}.svg"
        doc = data[floor]
        nav_graph, room_to_node, exit_to_node, objects = floorplan_json_generator(doc)
        if building not in node_data:
            node_data[building] = {"path": building_path,
                                   "floors" : {}
                                  }
        node_data[building]["floors"][floor] = {"plan": svg_file,
                                      "navigationGraph" : nav_graph,
                                      "roomToNode": room_to_node,
                                      "exitToNode": exit_to_node,
                                      "objects": objects}

from pathlib import Path
import json

parent = Path.cwd().parent          # folder that contains your cwd
outfile = parent / "all_node_data.json"

with open(outfile, "w") as f:
    json.dump(node_data, f, indent=4)

# %%
pprint(node_data)
# Out:
# {'Building A': {'floors': {'1': {'exitToNode': {},
#                                  'navigationGraph': {},
#                                  'objects': {'exits': {}, 'rooms': {}},
#                                  'plan': 'A1.svg',
#                                  'roomToNode': {}}},
#                 'path': 'Floorplans/Building A'},
#  'Building B': {'floors': {'1': {'exitToNode': {},
#                                  'navigationGraph': {},
#                                  'objects': {'exits': {}, 'rooms': {}},
#                                  'plan': 'B1.svg',
#                                  'roomToNode': {}}},
#                 'path': 'Floorplans/Building B'},
#  'Building H': {'floors': {'1': {'exitToNode': {'Elevator-H': 'H1_3',
#                                                 'F-Building': 'H1_17',
#                                                 'M1_entry': 'M1_entry',
#                                                 'Outside-Exit_1': 'H1_4',
#                                                 'Outside-Exit_2': 'H1_17',
#                                                 'Outside-Exit_3': 'H1_18',
#                                                 'Outside-Exit_4': 'H1_28',
#                                                 'Stairs_1': 'H1_4',
#                                                 'Stairs_2': 'H1_16',
#                                                 'Stairs_3': 'H1_28'},
#                                  'navigationGraph': {'H1_1': {'connections': ['H1_Turn_1',
#                                                                               'H1_2'],
#                                                               'represents': [{'door': 'Door_misc',
#                                                                               'id': 'Room_misc',
#                                                                               'type': 'room'}]},
#                                                      'H1_10': {'connections': ['H1_9',
#                                                                                'H1_11'],
#                                                                'represents': [{'door': 'Door_Bathroom-Women',
#                                                                                'id': 'Bathroom-Women',
#                                                                                'type': 'bathroom'},
#                                                                               {'door': 'Door_Cafe_1',
#                                                                                'id': 'Cafeteria-H',
#                                                                                'type': 'eatery'}]},
#                                                      'H1_11': {'connections': ['H1_10',
#                                                                                'H1_12'],
#                                                                'represents': [{'door': 'Door_1017',
#                                                                                'id': 'Room_1017',
#                                                                                'type': 'room'}]},
#                                                      'H1_12': {'connections': ['H1_11',
#                                                                                'H1_13'],
#                                                                'represents': [{'door': 'Door_1006',
#                                                                                'id': 'Room_1006',
#                                                                                'type': 'room'}]},
#                                                      'H1_13': {'connections': ['H1_12',
#                                                                                'H1_14'],
#                                                                'represents': [{'door': 'Door_1005_2',
#                                                                                'id': 'Room_1005',
#                                                                                'type': 'room'}]},
#                                                      'H1_14': {'connections': ['H1_13',
#                                                                                'H1_15'],
#                                                                'represents': [{'door': 'Door_1005_1',
#                                                                                'id': 'Room_1005',
#                                                                                'type': 'room'},
#                                                                               {'door': 'Door_1004',
#                                                                                'id': 'Room_1004',
#                                                                                'type': 'room'}]},
#                                                      'H1_15': {'connections': ['H1_14',
#                                                                                'H1_16'],
#                                                                'represents': [{'door': 'Door_1003',
#                                                                                'id': 'Room_1003',
#                                                                                'type': 'room'}]},
#                                                      'H1_16': {'connections': ['H1_15',
#                                                                                'H1_17'],
#                                                                'represents': [{'goesTo': ['H2',
#                                                                                           'H3'],
#                                                                                'id': 'Stairs_2',
#                                                                                'type': 'stairs'}]},
#                                                      'H1_17': {'connections': ['H1_Int_2'],
#                                                                'represents': [{'goesTo': ['outside'],
#                                                                                'id': 'Outside-Exit_2',
#                                                                                'type': 'outside_exit'},
#                                                                               {'goesTo': ['F1'],
#                                                                                'id': 'F-Building',
#                                                                                'type': 'building_connection'}]},
#                                                      'H1_18': {'connections': ['H1_Int_2'],
#                                                                'represents': [{'goesTo': ['outside'],
#                                                                                'id': 'Outside-Exit_3',
#                                                                                'type': 'outside_exit'}]},
#                                                      'H1_19': {'connections': ['H1_Int_1',
#                                                                                'H1_20'],
#                                                                'represents': [{'door': 'Door_1019',
#                                                                                'id': 'Room_1019',
#                                                                                'type': 'nan'}]},
#                                                      'H1_2': {'connections': ['H1_1',
#                                                                               'H1_Int_1'],
#                                                               'represents': [{'door': 'Door_1017',
#                                                                               'id': 'Room_1017',
#                                                                               'type': 'room'}]},
#                                                      'H1_20': {'connections': ['H1_19',
#                                                                                'H1_21'],
#                                                                'represents': [{'id': 'Room_1023',
#                                                                                'type': 'nan'}]},
#                                                      'H1_21': {'connections': ['H1_20',
#                                                                                'H1_22'],
#                                                                'represents': [{'door': 'Door_1024',
#                                                                                'id': 'Room_1024',
#                                                                                'type': 'nan'}]},
#                                                      'H1_22': {'connections': ['H1_21',
#                                                                                'H1_23'],
#                                                                'represents': [{'door': 'Door_Cafe_2',
#                                                                                'id': 'Cafeteria-H',
#                                                                                'type': 'eatery'}]},
#                                                      'H1_23': {'connections': ['H1_22',
#                                                                                'H1_24'],
#                                                                'represents': []},
#                                                      'H1_24': {'connections': ['H1_23',
#                                                                                'H1_25'],
#                                                                'represents': []},
#                                                      'H1_25': {'connections': ['H1_24',
#                                                                                'H1_26'],
#                                                                'represents': [{'door': 'Door_1032',
#                                                                                'id': 'Room_1032',
#                                                                                'type': 'room'}]},
#                                                      'H1_26': {'connections': ['H1_25',
#                                                                                'H1_27'],
#                                                                'represents': [{'door': 'Door_1034',
#                                                                                'id': 'Room_1034',
#                                                                                'type': 'room'}]},
#                                                      'H1_27': {'connections': ['H1_26',
#                                                                                'H1_28'],
#                                                                'represents': [{'door': 'Door_1033',
#                                                                                'id': 'Room_1033',
#                                                                                'type': 'room'}]},
#                                                      'H1_28': {'connections': ['H1_27'],
#                                                                'represents': [{'goesTo': ['H2',
#                                                                                           'H3'],
#                                                                                'id': 'Stairs_3',
#                                                                                'type': 'stairs'},
#                                                                               {'goesTo': ['outside'],
#                                                                                'id': 'Outside-Exit_4',
#                                                                                'type': 'outside_exit'}]},
#                                                      'H1_3': {'connections': ['H1_Int_1',
#                                                                               'H1_4'],
#                                                               'represents': [{'goesTo': ['H2',
#                                                                                          'H3'],
#                                                                               'id': 'Elevator-H',
#                                                                               'type': 'elevator'}]},
#                                                      'H1_4': {'connections': ['H1_3'],
#                                                               'represents': [{'goesTo': ['H2',
#                                                                                          'H3'],
#                                                                               'id': 'Stairs_1',
#                                                                               'type': 'stairs'},
#                                                                              {'goesTo': ['outside'],
#                                                                               'id': 'Outside-Exit_1',
#                                                                               'type': 'outside_exit'}]},
#                                                      'H1_5': {'connections': ['H1_Int_1',
#                                                                               'H1_6'],
#                                                               'represents': [{'door': 'Door_1016',
#                                                                               'id': 'Room_1016',
#                                                                               'type': 'room'}]},
#                                                      'H1_6': {'connections': ['H1_5',
#                                                                               'H1_7'],
#                                                               'represents': [{'door': 'Door_1015',
#                                                                               'id': 'Room_1015',
#                                                                               'type': 'room'}]},
#                                                      'H1_7': {'connections': ['H1_6',
#                                                                               'H1_8'],
#                                                               'represents': [{'door': 'Door_1014',
#                                                                               'id': 'Room_1014',
#                                                                               'type': 'room'}]},
#                                                      'H1_8': {'connections': ['H1_7',
#                                                                               'H1_9'],
#                                                               'represents': [{'door': 'Door_Bathroom-Men',
#                                                                               'id': 'Bathroom-Men',
#                                                                               'type': 'bathroom'}]},
#                                                      'H1_9': {'connections': ['H1_8',
#                                                                               'H1_10'],
#                                                               'represents': [{'door': 'Door_Bathroom-Accessible',
#                                                                               'id': 'Bathroom-Accessible',
#                                                                               'type': 'bathroom'}]},
#                                                      'H1_Int_1': {'connections': ['H1_2',
#                                                                                   'H1_3',
#                                                                                   'H1_5',
#                                                                                   'H1_19'],
#                                                                   'represents': [{'type': 'intersection'}]},
#                                                      'H1_Int_2': {'connections': ['H1_16',
#                                                                                   'H1_17',
#                                                                                   'H1_18'],
#                                                                   'represents': [{'type': 'intersection'}]},
#                                                      'H1_Turn_1': {'connections': ['M1_entry',
#                                                                                    'H1_1'],
#                                                                    'represents': [{'type': 'turn'}]},
#                                                      'M1_entry': {'connections': ['H1_Turn_1'],
#                                                                   'represents': [{'goesTo': ['M1'],
#                                                                                   'id': 'M1_entry',
#                                                                                   'type': 'building_connection'}]}},
#                                  'objects': {'exits': {'Elevator-H': ['H2',
#                                                                       'H3'],
#                                                        'F-Building': ['F1'],
#                                                        'M1_entry': ['M1'],
#                                                        'Outside-Exit_1': ['outside'],
#                                                        'Outside-Exit_2': ['outside'],
#                                                        'Outside-Exit_3': ['outside'],
#                                                        'Outside-Exit_4': ['outside'],
#                                                        'Stairs_1': ['H2', 'H3'],
#                                                        'Stairs_2': ['H2', 'H3'],
#                                                        'Stairs_3': ['H2',
#                                                                     'H3']},
#                                              'rooms': {'Bathroom-Accessible': ['Door_Bathroom-Accessible'],
#                                                        'Bathroom-Men': ['Door_Bathroom-Men'],
#                                                        'Bathroom-Women': ['Door_Bathroom-Women'],
#                                                        'Cafeteria-H': ['Door_Cafe_1',
#                                                                        'Door_Cafe_2'],
#                                                        'Room_1003': ['Door_1003'],
#                                                        'Room_1004': ['Door_1004'],
#                                                        'Room_1005': ['Door_1005_2',
#                                                                      'Door_1005_1'],
#                                                        'Room_1006': ['Door_1006'],
#                                                        'Room_1014': ['Door_1014'],
#                                                        'Room_1015': ['Door_1015'],
#                                                        'Room_1016': ['Door_1016'],
#                                                        'Room_1017': ['Door_1017',
#                                                                      'Door_1017'],
#                                                        'Room_1019': ['Door_1019'],
#                                                        'Room_1022': ['Door_1022'],
#                                                        'Room_1024': ['Door_1024'],
#                                                        'Room_1032': ['Door_1032'],
#                                                        'Room_1033': ['Door_1033'],
#                                                        'Room_1034': ['Door_1034'],
#                                                        'Room_misc': ['Door_misc']}},
#                                  'plan': 'H1.svg',
#                                  'roomToNode': {'Bathroom-Accessible': 'H1_9',
#                                                 'Bathroom-Men': 'H1_8',
#                                                 'Bathroom-Women': 'H1_10',
#                                                 'Cafeteria-H': 'H1_22',
#                                                 'Room_1003': 'H1_15',
#                                                 'Room_1004': 'H1_14',
#                                                 'Room_1005': 'H1_14',
#                                                 'Room_1006': 'H1_12',
#                                                 'Room_1014': 'H1_7',
#                                                 'Room_1015': 'H1_6',
#                                                 'Room_1016': 'H1_5',
#                                                 'Room_1017': 'H1_11',
#                                                 'Room_1019': 'H1_19',
#                                                 'Room_1024': 'H1_21',
#                                                 'Room_1032': 'H1_25',
#                                                 'Room_1033': 'H1_27',
#                                                 'Room_1034': 'H1_26',
#                                                 'Room_misc': 'H1_1'}}},
#                 'path': 'Floorplans/Building H'},
#  'Building M': {'floors': {'1': {'exitToNode': {'Elevator-M': 'M1_5',
#                                                 'H-Building': 'H_entry',
#                                                 'Outside-Exit_1': 'M1_7',
#                                                 'Outside-Exit_2': 'M1_2',
#                                                 'Outside-Exit_3': 'M1_13',
#                                                 'Outside-Exit_4': 'M1_19',
#                                                 'Stairs_1': 'M1_2',
#                                                 'Stairs_2': 'M1_13',
#                                                 'Stairs_3': 'M1_19'},
#                                  'navigationGraph': {'H_entry': {'connections': ['M1_1'],
#                                                                  'represents': [{'goesTo': ['H1'],
#                                                                                  'id': 'H-Building',
#                                                                                  'type': 'building_connection'}]},
#                                                      'M1_1': {'connections': ['H_entry',
#                                                                               'M1_2'],
#                                                               'represents': []},
#                                                      'M1_10': {'connections': ['M1_9',
#                                                                                'M1_11'],
#                                                                'represents': [{'door': 'Door_Bathroom-Accessible',
#                                                                                'id': 'Bathroom-Accessible',
#                                                                                'type': 'bathroom'}]},
#                                                      'M1_11': {'connections': ['M1_10',
#                                                                                'M1_12'],
#                                                                'represents': [{'door': 'Door_Bathroom-Women',
#                                                                                'id': 'Bathroom-Women',
#                                                                                'type': 'bathroom'}]},
#                                                      'M1_12': {'connections': ['M1_11',
#                                                                                'M1_Turn_2'],
#                                                                'represents': [{'door': 'Door_1033',
#                                                                                'id': 'Room_1033',
#                                                                                'type': 'room'}]},
#                                                      'M1_13': {'connections': ['M1_Turn_2'],
#                                                                'represents': [{'goesTo': ['M2',
#                                                                                           'M3'],
#                                                                                'id': 'Stairs_2',
#                                                                                'type': 'stairs'},
#                                                                               {'goesTo': ['outside'],
#                                                                                'id': 'Outside-Exit_3',
#                                                                                'type': 'outside_exit'}]},
#                                                      'M1_14': {'connections': ['M1_Int_2',
#                                                                                'M1_15'],
#                                                                'represents': [{'door': 'Door_1035',
#                                                                                'id': 'Room_1035',
#                                                                                'type': 'nan'}]},
#                                                      'M1_15': {'connections': ['M1_14',
#                                                                                'M1_16'],
#                                                                'represents': [{'door': 'Door_1037',
#                                                                                'id': 'Room_1037',
#                                                                                'type': 'nan'}]},
#                                                      'M1_16': {'connections': ['M1_15',
#                                                                                'M1_Turn_3'],
#                                                                'represents': [{'door': 'Door_1030',
#                                                                                'id': 'Room_1030',
#                                                                                'type': 'nan'}]},
#                                                      'M1_17': {'connections': ['M1_Turn_3',
#                                                                                'M1_18'],
#                                                                'represents': [{'door': 'Door_1040',
#                                                                                'id': 'Room_1040',
#                                                                                'type': 'nan'}]},
#                                                      'M1_18': {'connections': ['M1_17',
#                                                                                'M1_19'],
#                                                                'represents': [{'door': 'Door_1049',
#                                                                                'id': 'Room_1049',
#                                                                                'type': 'nan'}]},
#                                                      'M1_19': {'connections': ['M1_18'],
#                                                                'represents': [{'goesTo': ['outside'],
#                                                                                'id': 'Outside-Exit_4',
#                                                                                'type': 'outside_exit'},
#                                                                               {'goesTo': ['M2',
#                                                                                           'M3'],
#                                                                                'id': 'Stairs_3',
#                                                                                'type': 'stairs'}]},
#                                                      'M1_2': {'connections': ['M1_1',
#                                                                               'M1_3'],
#                                                               'represents': [{'goesTo': ['M2',
#                                                                                          'M3'],
#                                                                               'id': 'Stairs_1',
#                                                                               'type': 'stairs'},
#                                                                              {'goesTo': ['outside'],
#                                                                               'id': 'Outside-Exit_2',
#                                                                               'type': 'outside_exit'}]},
#                                                      'M1_3': {'connections': ['M1_2',
#                                                                               'M1_4'],
#                                                               'represents': [{'door': 'Door_1006',
#                                                                               'id': 'Room_1006',
#                                                                               'type': 'room'}]},
#                                                      'M1_4': {'connections': ['M1_Int_1',
#                                                                               'M1_5'],
#                                                               'represents': [{'door': 'Door_1004',
#                                                                               'id': 'Room_1004',
#                                                                               'type': 'room'}]},
#                                                      'M1_5': {'connections': ['M1_4',
#                                                                               'M1_6'],
#                                                               'represents': [{'goesTo': ['M2',
#                                                                                          'M3'],
#                                                                               'id': 'Elevator-M',
#                                                                               'type': 'elevator'}]},
#                                                      'M1_6': {'connections': ['M1_5',
#                                                                               'M1_7'],
#                                                               'represents': [{'type': 'turn'},
#                                                                              {'door': 'Door_1003_1',
#                                                                               'id': 'Room_1003',
#                                                                               'type': 'room'}]},
#                                                      'M1_7': {'connections': ['M1_6'],
#                                                               'represents': [{'goesTo': ['outside'],
#                                                                               'id': 'Outside-Exit_1',
#                                                                               'type': 'outside_exit'}]},
#                                                      'M1_8': {'connections': ['M1_Turn_1',
#                                                                               'M1_Int_2'],
#                                                               'represents': [{'door': 'Door_1018',
#                                                                               'id': 'Room_1018',
#                                                                               'type': 'room'}]},
#                                                      'M1_9': {'connections': ['M1_Int_2',
#                                                                               'M1_10'],
#                                                               'represents': [{'door': 'Door_Bathroom-Men',
#                                                                               'id': 'Bathroom-Men',
#                                                                               'type': 'bathroom'}]},
#                                                      'M1_Int_1': {'connections': ['M1_3',
#                                                                                   'M1_4',
#                                                                                   'M1_Turn_1'],
#                                                                   'represents': [{'type': 'intersection'}]},
#                                                      'M1_Int_2': {'connections': ['M1_8',
#                                                                                   'M1_9',
#                                                                                   'M1_14'],
#                                                                   'represents': [{'type': 'intersection'},
#                                                                                  {'door': 'Door_1003_2',
#                                                                                   'id': 'Room_1003',
#                                                                                   'type': 'room'}]},
#                                                      'M1_Turn_1': {'connections': ['M1_Int_1',
#                                                                                    'M1_8'],
#                                                                    'represents': [{'type': 'turn'}]},
#                                                      'M1_Turn_2': {'connections': ['M1_12',
#                                                                                    'M1_13'],
#                                                                    'represents': [{'type': 'turn'}]},
#                                                      'M1_Turn_3': {'connections': ['M1_16',
#                                                                                    'M1_17'],
#                                                                    'represents': [{'type': 'turn'},
#                                                                                   {'door': 'Door_1045',
#                                                                                    'id': 'Room_1045',
#                                                                                    'type': 'room'}]}},
#                                  'objects': {'exits': {'Elevator-M': ['M2',
#                                                                       'M3'],
#                                                        'H-Building': ['H1'],
#                                                        'Outside-Exit_1': ['outside'],
#                                                        'Outside-Exit_2': ['outside'],
#                                                        'Outside-Exit_3': ['outside'],
#                                                        'Outside-Exit_4': ['outside'],
#                                                        'Stairs_1': ['M2', 'M3'],
#                                                        'Stairs_2': ['M2', 'M3'],
#                                                        'Stairs_3': ['M2',
#                                                                     'M3']},
#                                              'rooms': {'Bathroom-Accessible': ['Door_Bathroom-Accessible'],
#                                                        'Bathroom-Men': ['Door_Bathroom-Men'],
#                                                        'Bathroom-Women': ['Door_Bathroom-Women'],
#                                                        'Room_1003': ['Door_1003_1',
#                                                                      'Door_1003_2'],
#                                                        'Room_1004': ['Door_1004'],
#                                                        'Room_1006': ['Door_1006'],
#                                                        'Room_1018': ['Door_1018'],
#                                                        'Room_1030': ['Door_1030'],
#                                                        'Room_1033': ['Door_1033'],
#                                                        'Room_1035': ['Door_1035'],
#                                                        'Room_1037': ['Door_1037'],
#                                                        'Room_1040': ['Door_1040'],
#                                                        'Room_1041': ['Door_1041'],
#                                                        'Room_1045': ['Door_1045'],
#                                                        'Room_1049': ['Door_1049']}},
#                                  'plan': 'M1.svg',
#                                  'roomToNode': {'Bathroom-Accessible': 'M1_10',
#                                                 'Bathroom-Men': 'M1_9',
#                                                 'Bathroom-Women': 'M1_11',
#                                                 'Room_1003': 'M1_Int_2',
#                                                 'Room_1004': 'M1_4',
#                                                 'Room_1006': 'M1_3',
#                                                 'Room_1018': 'M1_8',
#                                                 'Room_1030': 'M1_16',
#                                                 'Room_1033': 'M1_12',
#                                                 'Room_1035': 'M1_14',
#                                                 'Room_1037': 'M1_15',
#                                                 'Room_1040': 'M1_17',
#                                                 'Room_1045': 'M1_Turn_3',
#                                                 'Room_1049': 'M1_18'}}},
#                 'path': 'Floorplans/Building M'}}
